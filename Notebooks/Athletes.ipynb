# %%
import pandas as pd

# %%
athletes = pd.read_excel("../Output/Athletes_clean.xlsx", engine="openpyxl")

# %%
athletes
# Out:
#                   First Last      NOC           Discipline  Unnamed: 3  \
# 0            Katrine Aalerud   Norway         Cycling Road         NaN
# 1                Nestor Abad    Spain  Artistic Gymnastics         NaN
# 2          Giovanni Abagnale    Italy               Rowing         NaN
# 3             Alberto Abalde    Spain           Basketball         NaN
# 4              Tamara Abalde    Spain           Basketball         NaN
# ...                      ...      ...                  ...         ...
# 11080  Martin Detlef Zwicker  Germany               Hockey         NaN
# 11081      Klaudia Zwolinska   Poland         Canoe Slalom         NaN
# 11082           Yulia Zykova      ROC             Shooting         NaN
# 11083      Ekaterina Zyuzina      ROC              Sailing         NaN
# 11084        Sylwia Zyzanska   Poland              Archery         NaN
#
#        Unnamed: 4  Unnamed: 5
# 0             NaN         NaN
# 1             NaN         NaN
# ...

# %%
athletes_clean=athletes.copy()
athletes_clean = athletes_clean[["First Last", "NOC"]]
athletes_clean
# Out:
#                   First Last      NOC
# 0            Katrine Aalerud   Norway
# 1                Nestor Abad    Spain
# 2          Giovanni Abagnale    Italy
# 3             Alberto Abalde    Spain
# 4              Tamara Abalde    Spain
# ...                      ...      ...
# 11080  Martin Detlef Zwicker  Germany
# 11081      Klaudia Zwolinska   Poland
# 11082           Yulia Zykova      ROC
# 11083      Ekaterina Zyuzina      ROC
# 11084        Sylwia Zyzanska   Poland
#
# [11085 rows x 2 columns]

# %%
athletes_clean.drop_duplicates()
# Out:
#                   First Last      NOC
# 0            Katrine Aalerud   Norway
# 1                Nestor Abad    Spain
# 2          Giovanni Abagnale    Italy
# 3             Alberto Abalde    Spain
# 4              Tamara Abalde    Spain
# ...                      ...      ...
# 11080  Martin Detlef Zwicker  Germany
# 11081      Klaudia Zwolinska   Poland
# 11082           Yulia Zykova      ROC
# 11083      Ekaterina Zyuzina      ROC
# 11084        Sylwia Zyzanska   Poland
#
# [11071 rows x 2 columns]

# %%
athletes_clean.to_csv("../Output/Athletes.csv")
